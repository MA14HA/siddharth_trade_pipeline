# %%
import sys
import os

# Get the path to the root directory (siddharth_trade_pipeline/)
# The '../' moves up one level from the 'notebooks' folder.
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Add the project root to the system path
if project_root not in sys.path:
    sys.path.append(project_root)

print(f"Project root added to path: {project_root}")
# Out:
# Project root added to path: C:\Users\Home\OneDrive\Desktop\Assign\siddharth_trade_pipeline

# %%
# Assuming you've already defined your path setup and loaded the modules

from src.db.load_to_db import load_data_to_postgres

# %%
# Define paths
CLEANED_CSV = '../data/processed/trade_cleaned.csv' # This file holds the result of Phase 3

# %%
# Run the loader
load_data_to_postgres(CLEANED_CSV, table_name='shipments')
# Out:
# Loaded 2079 rows from CSV: ../data/processed/trade_cleaned.csv
# DataFrame columns standardized to snake_case.
# Successfully loaded data into PostgreSQL table 'shipments'.
